# %%
import pandas as pd
import numpy as np
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
#For using column names
df_boston = pd.DataFrame(data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])
df_boston['PRICE'] = target
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_447/1767258651.py:4: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
#ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#INDUS    proportion of non-retail business acres per town
#CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#NOX      nitric oxides concentration (parts per 10 million)
#RM       average number of rooms per dwelling
#AGE      proportion of owner-occupied units built prior to 1940
#DIS      weighted distances to five Boston employment centres
#RAD      index of accessibility to radial highways
#TAX      full-value property-tax rate per $10,000
#PTRATIO  pupil-teacher ratio by town
#B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#LSTAT    % lower status of the population
#MEDV     Median value of owner-occupied homes in $1000's

# %%
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48   22.0
# ...

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df_boston.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df_boston.shape
# Out:
# (506, 14)

# %%
x = df_boston.drop('PRICE', axis = 1) #multiple linear regression # Method 1

# %%
#anotherway of taking dependent variables if and only if the dataset having its target colums in the last
x = df_boston.iloc[:,:-1] # method 2

# %%
y = df_boston['PRICE']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %% [markdown]
# Model building

# %%
import statsmodels.api as sm
xc = sm.add_constant(x)
ols_model= sm.OLS(y, xc).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Tue, 24 Mar 2026   Prob (F-statistic):          6.72e-135
# Time:                        14:29:37   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %%
y_pred = ols_model.fittedvalues
residuals = ols_model.resid
y_pred
# Out:
# 0      30.003843
# 1      25.025562
# 2      30.567597
# 3      28.607036
# 4      27.943524
#          ...
# 501    23.533341
# 502    22.375719
# 503    27.627426
# 504    26.127967
# 505    22.344212
# Length: 506, dtype: float64

# %% [markdown]
# Assumption 1 : No Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF

# %%
xc.columns
# Out:
# Index(['const', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
VIF(xc.values,1) #It gives values fpr 1st colums as target variable then others are predicted variable
# Out:
# np.float64(1.7921915474332413)

# %%
VIF(xc.values,2)
# Out:
# np.float64(2.298758178749441)

# %%
vif_values = [VIF(xc.values,i) for i in range (xc.shape[1])]
DF1 = pd.DataFrame(vif_values, columns = ['VIF Value'], index = xc.columns).sort_values(by = 'VIF Value', ascending = False)

# %%
DF1
# Out:
#           VIF Value
# const    585.265238
# TAX        9.008554
# RAD        7.484496
# NOX        4.393720
# INDUS      3.991596
# DIS        3.955945
# AGE        3.100826
# LSTAT      2.941491
# ZN         2.298758
# RM         1.933744
# PTRATIO    1.799084
# CRIM       1.792192
# B          1.348521
# CHAS       1.073995

# %%
# due to multicolinearity remove tax column

# %%
x = df_boston.drop(['TAX'], axis = 1)
xc = sm.add_constant(x)

# %%
xc
# Out:
#      const     CRIM    ZN  INDUS  CHAS  ...  RAD  PTRATIO       B  LSTAT  PRICE
# 0      1.0  0.00632  18.0   2.31   0.0  ...  1.0     15.3  396.90   4.98   24.0
# 1      1.0  0.02731   0.0   7.07   0.0  ...  2.0     17.8  396.90   9.14   21.6
# 2      1.0  0.02729   0.0   7.07   0.0  ...  2.0     17.8  392.83   4.03   34.7
# 3      1.0  0.03237   0.0   2.18   0.0  ...  3.0     18.7  394.63   2.94   33.4
# 4      1.0  0.06905   0.0   2.18   0.0  ...  3.0     18.7  396.90   5.33   36.2
# ..     ...      ...   ...    ...   ...  ...  ...      ...     ...    ...    ...
# 501    1.0  0.06263   0.0  11.93   0.0  ...  1.0     21.0  391.99   9.67   22.4
# 502    1.0  0.04527   0.0  11.93   0.0  ...  1.0     21.0  396.90   9.08   20.6
# 503    1.0  0.06076   0.0  11.93   0.0  ...  1.0     21.0  396.90   5.64   23.9
# 504    1.0  0.10959   0.0  11.93   0.0  ...  1.0     21.0  393.45   6.48   22.0
# 505    1.0  0.04741   0.0  11.93   0.0  ...  1.0     21.0  396.90   7.88   11.9
#
# ...

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
vif_values = [VIF(xc.values,i) for i in range (xc.shape[1])]
DF1 = pd.DataFrame(vif_values, columns = ['VIF Value'], index = xc.columns).sort_values('VIF Value', ascending = False)

# %%
DF1
# Out:
#           VIF Value
# const    631.860301
# NOX        4.578751
# DIS        4.392557
# PRICE      3.773177
# LSTAT      3.561127
# INDUS      3.235660
# AGE        3.098057
# RAD        2.898743
# RM         2.260029
# ZN         2.216337
# PTRATIO    1.991741
# CRIM       1.829538
# B          1.381446
# CHAS       1.084627

# %% [markdown]
# Model building

# %%
ols_model = sm.OLS(y, xc).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.741e+30
# Date:                Tue, 24 Mar 2026   Prob (F-statistic):               0.00
# Time:                        14:29:38   Log-Likelihood:                 15159.
# No. Observations:                 506   AIC:                        -3.029e+04
# Df Residuals:                     492   BIC:                        -3.023e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.908e-14   2.67e-14      1.462      0.144   -1.34e-14    9.16e-14
# ...

# %% [markdown]
# Assumptions After Model Building

# %%
y_pred= ols_model.fittedvalues
residual = ols_model.resid

# %%
import matplotlib.pyplot as plt
plt.scatter(y_pred, residual)

# %% [markdown]
# 1. linear reltionship between dependent and independent variables

# %%
# to test linearity
from statsmodels.stats.api import linear_rainbow
test_stat, p_values = linear_rainbow(ols_model)

# %%
test_stat, p_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15696/3664590198.py in <cell line: 0>()
# ----> 1 test_stat, p_values
#
# NameError: name 'test_stat' is not defined

# %% [markdown]
# linearity test assumption checked it is linear

# %% [markdown]
# **After Model Building Tests**

# %% [markdown]
# 2. independence of observations should exist (i.e Absence Of Autocorrection)

# %%
from statsmodels.stats.stattools import durbin_watson

# %%
durbin_watson(residual)

# %% [markdown]
# Assumption 4 : Homoscedasticity (No Heteroscedasticity)

# %% [markdown]
# variance among residuals equal

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

# %% [markdown]
# Assumption 5 - Normality Test

# %%
import scipy.stats as stats

# %%
stats.shapiro(residual)
# Out:
# ShapiroResult(statistic=np.float64(0.9766931371271477), pvalue=np.float64(3.20119152061915e-07))

# %%
from statsmodels.api import qqplot

# %%
qqplot(residual, line='r')

# %%
stats.probplot(residuals, plot = plt)
plt.show()
